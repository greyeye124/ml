# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
df=pdr.get_data_stooq('TSLA')
df
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2023-04-27  152.6400  160.4800  152.3700  160.1900  126483576
# 2023-04-26  160.2900  160.6700  153.1400  153.7500  153364142
# 2023-04-25  159.8200  163.4700  158.7500  160.6700  121999312
# 2023-04-24  164.6500  165.6500  158.6100  162.5500  140006559
# 2023-04-21  164.8000  166.0000  161.3208  165.0800  123538954
# ...              ...       ...       ...       ...        ...
# 2018-05-04   18.8667   19.7907   18.6347   19.6060  128540310
# 2018-05-03   18.5860   19.2027   18.3487   18.9633  260281950
# 2018-05-02   19.9047   20.4567   19.8523   20.0767  134555550
# 2018-05-01   19.5673   20.0547   19.5480   19.9947   69384045
# 2018-04-30   19.5740   19.9153   19.5000   19.5933   63422580
#
# [1258 rows x 5 columns]

# %% [markdown]
# Simple moving average: smoothing a curve by taking an average of data accross a certain window, i.e maybe 10 entries at a time and finding average, then finding average for i+1 to i+11th, then i+2 to i+12th, going on and on till you reach the end of the data.
# # New Section

# %%
df['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Open:10 days rolling']=df['Open'].rolling(window=10,min_periods=1).mean()

# %% [markdown]
# df[newcolumn]=df[oldcolumn].rolling(window=window_size,period=period_size).mean()

# %%
df[['Open','Open:10 days rolling']].plot(xlim=['2020-01-01','2021-01-01'])
# Out:
# <Axes: xlabel='Date'>

# %%
df['Open'].expanding().mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Open'].ewm(halflife=10).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# formula for ema ⚛
# (close-prev ema)*multiplier  + prev ema

# %% [markdown]
# start with average for given window, then take next data point and find using formula;
# learnimg touch typimg as we go ehehehe

# %% [markdown]
# ARIMA: AR- Autoregression
# MA: Moving average.
# moving average models are
# for movin gaverages plots that can be used are
