# %%
import pandas_datareader as pdr

# %%
import pandas as pd
import datetime as dt

# %%
df = pdr.get_data_moex(['USD000UTSTOM', 'MAGN'], '2020-07-02', '2020-07-07')
# Out:
# <ipython-input-3-5abf920ffc09>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = pdr.get_data_moex(['USD000UTSTOM', 'MAGN'], '2020-07-02', '2020-07-07')
# <ipython-input-3-5abf920ffc09>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = pdr.get_data_moex(['USD000UTSTOM', 'MAGN'], '2020-07-02', '2020-07-07')

# %%
df.head()
# Out:
#            ACCINT  ADMITTEDQUOTE  ADMITTEDVALUE BEICLOSE  BID BOARDID  \
# TRADEDATE
# 2020-07-02    NaN            NaN            NaN      NaN  NaN    CETS
# 2020-07-03    NaN            NaN            NaN      NaN  NaN    CETS
# 2020-07-06    NaN            NaN            NaN      NaN  NaN    CETS
# 2020-07-07    NaN            NaN            NaN      NaN  NaN    CETS
# 2020-07-02    NaN         37.605    670695507.0      NaN  NaN    TQBR
#
#            BOARDNAME BUYBACKDATE CBRCLOSE    CLOSE  ... TYPE        VALUE  \
# TRADEDATE                                           ...
# 2020-07-02       NaN         NaN      NaN  70.5525  ...  NaN          NaN
# 2020-07-03       NaN         NaN      NaN  71.3700  ...  NaN          NaN
# 2020-07-06       NaN         NaN      NaN  71.8275  ...  NaN          NaN
# 2020-07-07       NaN         NaN      NaN  71.4725  ...  NaN          NaN
# 2020-07-02       NaN         NaN      NaN  37.6050  ...  NaN  670695507.0
#
# ...

# %%
import yfinance as yf
df=yf.download(tickers='TSLA',start='2017-02-27',end='2023-03-13',interval='1D',group_by='ticker')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2017-02-27  16.544666  16.557333  16.134001  16.415333  16.415333  171912000
# 2017-02-28  16.279333  16.733334  16.260000  16.666000  16.666000   91171500
# 2017-03-01  16.945333  16.990000  16.607332  16.667999  16.667999   72142500
# 2017-03-02  16.647333  16.885332  16.551332  16.698668  16.698668   50277000
# 2017-03-03  16.716000  16.793333  16.600000  16.771334  16.771334   43791000

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-03-06  198.539993  198.600006  192.300003  193.809998  193.809998
# 2023-03-07  191.380005  194.199997  186.100006  187.710007  187.710007
# 2023-03-08  185.039993  186.500000  180.000000  182.000000  182.000000
# 2023-03-09  180.250000  185.179993  172.509995  172.919998  172.919998
# 2023-03-10  175.130005  178.289993  168.440002  173.440002  173.440002
#
#                Volume
# Date
# 2023-03-06  128100100
# 2023-03-07  148125800
# 2023-03-08  151897800
# 2023-03-09  170023800
# 2023-03-10  191488900

# %%
df['High'].plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df['High'].plot(ylim=[0,800],xlim=['2020-09-09','2023-03-10'],c='brown',ls='--')
# Out:
# <Axes: xlabel='Date'>

# %%
df.head(4)
openshares=df.loc['2020-01-01':'2021-09-01']['Open']
index=df.loc['2020-01-01':'2021-09-01'].index

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis=plt.subplots()
figure.autofmt_xdate()
axis.plot(index,openshares)

# %%
df=df.reset_index()

# %%
pd.to_datetime(df['Date'])
# Out:
# 0      2017-02-27
# 1      2017-02-28
# 2      2017-03-01
# 3      2017-03-02
# 4      2017-03-03
#           ...
# 1515   2023-03-06
# 1516   2023-03-07
# 1517   2023-03-08
# 1518   2023-03-09
# 1519   2023-03-10
# Name: Date, Length: 1520, dtype: datetime64[ns]

# %%
df.set_index('Date',drop=True)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-02-27   16.544666   16.557333   16.134001   16.415333   16.415333
# 2017-02-28   16.279333   16.733334   16.260000   16.666000   16.666000
# 2017-03-01   16.945333   16.990000   16.607332   16.667999   16.667999
# 2017-03-02   16.647333   16.885332   16.551332   16.698668   16.698668
# 2017-03-03   16.716000   16.793333   16.600000   16.771334   16.771334
# ...                ...         ...         ...         ...         ...
# 2023-03-06  198.539993  198.600006  192.300003  193.809998  193.809998
# 2023-03-07  191.380005  194.199997  186.100006  187.710007  187.710007
# 2023-03-08  185.039993  186.500000  180.000000  182.000000  182.000000
# 2023-03-09  180.250000  185.179993  172.509995  172.919998  172.919998
# 2023-03-10  175.130005  178.289993  168.440002  173.440002  173.440002
#
#                Volume
# Date
# 2017-02-27  171912000
# 2017-02-28   91171500
# 2017-03-01   72142500
# ...

# %% [markdown]
# **TIME RESAMPLE
# **

# %%
df['date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
df.rolling(10).mean()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-02-27         NaN         NaN         NaN         NaN         NaN
# 2017-02-28         NaN         NaN         NaN         NaN         NaN
# 2017-03-01         NaN         NaN         NaN         NaN         NaN
# 2017-03-02         NaN         NaN         NaN         NaN         NaN
# 2017-03-03         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2023-03-06  200.207001  203.519000  195.285001  199.579001  199.579001
# 2023-03-07  198.846001  201.967999  194.173001  198.613002  198.613002
# 2023-03-08  197.557001  200.418999  192.995001  196.727002  196.727002
# 2023-03-09  195.191000  198.422998  190.613000  193.812001  193.812001
# 2023-03-10  193.071001  196.484998  188.177000  191.468001  191.468001
#
#                  Volume
# Date
# 2017-02-27          NaN
# 2017-02-28          NaN
# 2017-03-01          NaN
# ...

# %% [markdown]
# rolling and expanding
# rolling: a window is given, if axis is 0 then for rows and if 1 then column
# level and next level is selected till the winndow elapses

# %%
df['Open:30 days rolling']=df['Open'].rolling(30).mean()

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2017-02-27  16.544666  16.557333  16.134001  16.415333  16.415333  171912000
# 2017-02-28  16.279333  16.733334  16.260000  16.666000  16.666000   91171500
# 2017-03-01  16.945333  16.990000  16.607332  16.667999  16.667999   72142500
# 2017-03-02  16.647333  16.885332  16.551332  16.698668  16.698668   50277000
# 2017-03-03  16.716000  16.793333  16.600000  16.771334  16.771334   43791000
#
#             Open:30 days rolling
# Date
# 2017-02-27                   NaN
# 2017-02-28                   NaN
# 2017-03-01                   NaN
# 2017-03-02                   NaN
# 2017-03-03                   NaN

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-02-27   16.544666   16.557333   16.134001   16.415333   16.415333
# 2017-02-28   16.279333   16.733334   16.260000   16.666000   16.666000
# 2017-03-01   16.945333   16.990000   16.607332   16.667999   16.667999
# 2017-03-02   16.647333   16.885332   16.551332   16.698668   16.698668
# 2017-03-03   16.716000   16.793333   16.600000   16.771334   16.771334
# ...                ...         ...         ...         ...         ...
# 2023-03-06  198.539993  198.600006  192.300003  193.809998  193.809998
# 2023-03-07  191.380005  194.199997  186.100006  187.710007  187.710007
# 2023-03-08  185.039993  186.500000  180.000000  182.000000  182.000000
# 2023-03-09  180.250000  185.179993  172.509995  172.919998  172.919998
# 2023-03-10  175.130005  178.289993  168.440002  173.440002  173.440002
#
#                Volume  Open:30 days rolling
# Date
# 2017-02-27  171912000                   NaN
# ...

# %%
df[['Open','Open:30 days rolling']].plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# resampling data gives the crux of the data, and you can get the max or min value or plot graphs but resampling only works on time series data!!
